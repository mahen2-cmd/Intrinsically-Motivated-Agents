# %%
import visual
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
visual.player1_positions = [
    (0, 2),
    (0, 3),
    (1, 3),
    (1, 4),
    # (2, 4),
    # (3, 4),
    # (3, 3),
    # (3, 2),
    # (3, 1),
    # (4, 1),
    # (4, 1),
    # (4, 2),
    # (3, 2),
    # (3, 3),
    # (4, 3),
    # (5, 3),
    # (6, 3),
    # (7, 3),
    # (7, 4),
    # (8, 4),
    # (8, 3),
    # (8, 2),
    # (8, 1),
    # (8, 2),
    # (8, 3),
]
visual.player2_positions = [
    (3, 5),
    (2, 5),
    (3, 5),
    (3, 5),
    # (3, 4),
    # (4, 4),
    # (4, 3),
    # (3, 3),
    # (3, 2),
    # (3, 1),
    # (4, 1),
    # (4, 2),
    # (3, 2),
    # (3, 3),
    # (4, 3),
    # (5, 3),
    # (6, 3),
    # (7, 3),
    # (7, 4),
    # (8, 4),
    # (8, 3),
    # (8, 2),
    # (8, 1),
    # (8, 2),
    # (8, 3),
]
visual.movable_object = [
    (4, 2),
    (4, 2),
    (4, 2),
    (4, 2),
    # (4, 2),
    # (4, 2),
    # (4, 2),
    # (4, 2),
    # (4, 2),
    # (4, 2),
    # (4, 2),
    # (4, 3),
    # (4, 3),
    # (4, 3),
    # (5, 3),
    # (6, 3),
    # (7, 3),
    # (8, 3),
    # (8, 3),
    # (8, 3),
    # (8, 2),
    # (8, 1),
    # (8, 0),
    # (8, 0),
    # (8, 0),
]

# %%
game = visual.Game()
game.game_loop()
